# %% [markdown]
# <a href="https://colab.research.google.com/github/ArcticFoox/problem_solving_programming/blob/main/problem_solving_team_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from datetime import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')

X = pd.read_excel('drive/MyDrive/GX.xlsx')
y = pd.read_excel('drive/MyDrive/Gy.xlsx')
xy = pd.read_excel('drive/MyDrive/GXy.xlsx')
# Out:
# Mounted at /content/drive

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.displot(y['매매가격지수'])
sns.displot(np.log(y['매매가격지수']))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.jointplot(x = '총 출생아', y = '매매가격지수', data=xy, kind='reg', line_kws={'color':'blue'})
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52509 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52636 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49373 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50500 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.jointplot(x = '40이하', y = '매매가격지수', data=xy, kind='reg', line_kws={'color':'blue'})
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.jointplot(x = '60이하', y = '매매가격지수', data=xy, kind='reg', line_kws={'color':'blue'})
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.jointplot(x = '60초과 ~ 85이하', y = '매매가격지수', data=xy, kind='reg', line_kws={'color':'blue'})
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.jointplot(x = '85초과 ~ 102이하', y = '매매가격지수', data=xy, kind='reg', line_kws={'color':'blue'})
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.jointplot(x = '102초과 ~ 135이하', y = '매매가격지수', data=xy, kind='reg', line_kws={'color':'blue'})
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.jointplot(x = '135초과', y = '매매가격지수', data=xy, kind='reg', line_kws={'color':'blue'})
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.jointplot(x = '전세가', y = '매매가격지수', data=xy, kind='reg', line_kws={'color':'blue'})
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.jointplot(x = '매매 동향', y = '매매가격지수', data=xy, kind='reg', line_kws={'color':'blue'})
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54693 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
sns.jointplot(x = '총 전입인구', y = '매매가격지수', data=xy, kind='reg', line_kws={'color':'blue'})
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52509 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
xy[['매매가격지수', '40이하', '60이하', '60초과 ~ 85이하',
       '85초과 ~ 102이하', '102초과 ~ 135이하', '135초과',
       '전세가', '매매 동향', '총 전입인구', '총 출생아']].corr()
# Out:
#                  매매가격지수      40이하      60이하  60초과 ~ 85이하  85초과 ~ 102이하  \
# 매매가격지수         1.000000  0.029800  0.952582     0.843693      0.862288
# 40이하           0.029800  1.000000  0.165386     0.310185      0.321215
# 60이하           0.952582  0.165386  1.000000     0.923610      0.868102
# 60초과 ~ 85이하    0.843693  0.310185  0.923610     1.000000      0.777287
# 85초과 ~ 102이하   0.862288  0.321215  0.868102     0.777287      1.000000
# 102초과 ~ 135이하  0.814408  0.304411  0.898047     0.978446      0.706428
# 135초과          0.278242  0.273434  0.265531     0.456550      0.104082
# 전세가            0.913120  0.280135  0.984799     0.969127      0.869711
# 매매 동향          0.276808  0.282753  0.483238     0.556390      0.326359
# 총 전입인구        -0.041432  0.001238 -0.017873    -0.020481     -0.064068
# 총 출생아         -0.229870 -0.787113 -0.401409    -0.557541     -0.467835
#
#                102초과 ~ 135이하     135초과       전세가     매매 동향    총 전입인구     총 출생아
# ...

# %%
corrMat = xy[['매매가격지수', '40이하', '60이하', '60초과 ~ 85이하',
       '85초과 ~ 102이하', '102초과 ~ 135이하', '135초과',
       '전세가', '매매 동향', '총 전입인구', '총 출생아']].corr()
fig, ax = plt.subplots()
fig.set_size_inches(10,10)
sns.heatmap(corrMat, cmap = 'bwr', annot = True)
ax.set(title = 'Heatmap of numerical data')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
del X['매매 동향']
del X['총 전입인구']

# %%
del X['40㎡이하']
#del X['60㎡이하']
#del X['60㎡초과 ~ 85㎡이하']
#del X['85㎡초과 ~ 102㎡이하']
#del X['102㎡초과 ~ 135㎡이하']
del X['135㎡초과']
del X['총 출생아']

# %%
X_train = X[0:400]
X_test = X[400:]
y_train = y[0:400]
y_test = y[400:]

# %%
def RMSE(y_true, y_pred): #로그 치완이 필요없는 방법
  y_pred=y_pred.reshape(len(y_pred),1)
  output = np.sqrt(np.mean((y_true-y_pred)**2))
  return output

# %%
from sklearn.linear_model import LinearRegression
lin_model = LinearRegression()

# %%
lin_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lin_model.coef_
# Out:
# array([[ 1.68921910e+00,  7.58766569e-01,  5.78748763e-01,
#          2.28374970e-01, -2.43887940e+00, -1.13747291e-05,
#         -9.71416693e-05,  5.10893191e-03]])

# %%
lin_model.predict(X_train)
# Out:
# array([[ 95.06569458],
#        [ 95.06569458],
#        [ 94.86422594],
#        [ 94.84546081],
#        [ 94.95734549],
#        [ 94.98504125],
#        [ 94.98504125],
#        [ 94.95543876],
#        [ 94.80199407],
#        [ 94.70528698],
#        [ 94.71992298],
#        [ 94.77216385],
#        [ 94.73260562],
#        [ 95.04147133],
#        [ 95.17535818],
#        [ 95.22710342],
#        [ 95.1477198 ],
#        [ 95.27767551],
#        [ 95.25078997],
#        [ 95.20105489],
#        [ 95.16784764],
#        [ 95.15673516],
#        [ 95.14775703],
#        [ 95.1623811 ],
#        [ 95.1864491 ],
#        [ 95.24086982],
#        [ 94.80958579],
#        [ 94.83780586],
#        [ 94.77704864],
#        [ 94.78489273],
#        [ 94.74437087],
#        [ 94.58021623],
#        [ 94.6232473 ],
#        [ 94.63025959],
#        [ 94.63307807],
#        [ 94.99873912],
#        [ 95.03250858],
#        [ 95.01423261],
#        [ 94.72169454],
#        [ 94.31318053],
# ...

# %%
RMSE(y_train, lin_model.predict(X_train))
# Out:
# 매매가격지수    0.507147
# dtype: float64

# %%
plt.figure(figsize = (10,5))
x = np.linspace(70,150)
y = x
lines = plt.plot(x,y,'-r', lin_model.predict(X_train), y_train, 'o')
plt.xlabel('Predict')
plt.ylabel('Obseved')
plt.legend(('y = x', 'predict'),fontsize = 10, loc = 'best')

# %%
from sklearn.linear_model import Ridge

# %%
Ridge_model = Ridge(alpha=100)

# %%
Ridge_model.fit(X_train, y_train)
# Out:
# Ridge(alpha=100)

# %%
Ridge_model.coef_
# Out:
# array([[ 3.95329496e-01,  8.78187605e-02,  3.96134024e-01,
#         -8.17966758e-03,  1.46373624e-02, -3.00691569e-05,
#          6.37835292e-03,  6.87535511e-03]])

# %%
Ridge_model.intercept_
# Out:
# array([7.49701572])

# %%
Ridge_pred_train = Ridge_model.predict(X_train)
Ridge_pred_test = Ridge_model.predict(X_test)

# %%
Ridge_pred_train
# Out:
# array([[ 94.57162875],
#        [ 94.57162875],
#        [ 94.41891193],
#        [ 94.41777204],
#        [ 95.03373169],
#        [ 95.06230719],
#        [ 95.06230719],
#        [ 95.04630366],
#        [ 94.89765302],
#        [ 94.86357063],
#        [ 94.8942001 ],
#        [ 94.90884162],
#        [ 94.82417625],
#        [ 94.93760312],
#        [ 94.97975177],
#        [ 95.01309134],
#        [ 94.94025057],
#        [ 95.46905289],
#        [ 95.48344554],
#        [ 95.3823959 ],
#        [ 95.38177714],
#        [ 95.37009771],
#        [ 94.99637799],
#        [ 95.04505101],
#        [ 95.06996015],
#        [ 95.13337749],
#        [ 94.36992597],
#        [ 94.39215328],
#        [ 94.3238863 ],
#        [ 94.32052826],
#        [ 94.27132971],
#        [ 93.7116536 ],
#        [ 93.7421753 ],
#        [ 93.74093018],
#        [ 93.75961764],
#        [ 94.96983907],
#        [ 94.98788179],
#        [ 94.98383981],
#        [ 94.74403208],
#        [ 93.23413598],
# ...

# %%
RMSE(y_train, Ridge_pred_train)
# Out:
# 매매가격지수    0.639074
# dtype: float64

# %%
RMSE(y_test, Ridge_pred_test)
# Out:
# 매매가격지수    1.66953
# dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree

DT_model = DecisionTreeRegressor(max_depth=5)
DT_model.fit(X_train, y_train) # X_train = 학습시키는 특성

DT_pred_train = DT_model.predict(X_train)
DT_pred_test = DT_model.predict(X_test)

# %%
RMSE(y_train, DT_pred_train)
# Out:
# 매매가격지수    0.191764
# dtype: float64

# %%
RMSE(y_test, DT_pred_test)
# Out:
# 매매가격지수    1.733642
# dtype: float64

# %%
plt.figure(figsize = (10,5))
#     학습 결정트리 모델         특성값               #값 결정에 따른 색 칠하기
plot_tree(DT_model, feature_names= X_train.columns, filled = True);
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 13217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44284 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
print("특성 중요도:", DT_model.feature_importances_)
# Out:
# 특성 중요도: [8.08811149e-01 2.23245608e-04 0.00000000e+00 5.59558094e-02
#  1.25254151e-01 4.77178621e-04 0.00000000e+00 9.27846657e-03]

# %%
feature_importance=DT_model.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(X_train.columns)[sorted_idx])
plt.xlabel('Feature Importance')
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45224 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45224 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from sklearn.linear_model import LinearRegression
Lin_model=LinearRegression()
Lin_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
x=np.linspace(80,120)
y=x
lines=plt.plot(Lin_model.predict(X_train),y_train,'o',x,y,'k')
plt.setp(lines[0], markersize=7)
plt.setp(lines[1], linewidth=3)
plt.xlabel('Predicted')
plt.ylabel('Observed')
plt.title('Linear Regression (train)')
plt.tight_layout()

plt.subplot(1,2,2)
lines2=plt.plot(DT_model.predict(X_train),y_train,'o',x,y,'k')
plt.setp(lines[0], markersize=7)
plt.setp(lines[1], linewidth=3)
plt.xlabel('Predicted')
plt.ylabel('Observed')
plt.title('Random Forest (train)')
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
x=np.linspace(80,120)
y=x
lines=plt.plot(Lin_model.predict(X_test),y_test,'o',x,y,'k')
plt.setp(lines[0], markersize=7)
plt.setp(lines[1], linewidth=3)
plt.xlabel('Predicted')
plt.ylabel('Observed')
plt.title('Linear Regression (test)')
plt.tight_layout()

plt.subplot(1,2,2)
lines2=plt.plot(DT_model.predict(X_test),y_test,'o',x,y,'k')
plt.setp(lines[0], markersize=7)
plt.setp(lines[1], linewidth=3)
plt.xlabel('Predicted')
plt.ylabel('Observed')
plt.title('Random Forest (test)')
plt.tight_layout()

plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RF_model = RandomForestRegressor(random_state=42, n_estimators=10, max_depth=4)
RF_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(max_depth=4, n_estimators=10, random_state=42)

# %%
RF_pred_train = RF_model.predict(X_train)
RF_pred_test = RF_model.predict(X_test)

# %%
RMSE(y_train, RF_pred_train)
# Out:
# 매매가격지수    0.283344
# dtype: float64

# %%
RMSE(y_test, RF_pred_test)
# Out:
# 매매가격지수    2.02502
# dtype: float64

# %%
feature_importance=RF_model.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(X_train.columns)[sorted_idx])
plt.xlabel('Feature Importance')
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52509 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52636 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
x=np.linspace(80,120)
y=x
lines=plt.plot(Lin_model.predict(X_train),y_train,'o',x,y,'k')
plt.setp(lines[0], markersize=7)
plt.setp(lines[1], linewidth=3)
plt.xlabel('Predicted')
plt.ylabel('Observed')
plt.title('Linear Regression (train)')
plt.tight_layout()

plt.subplot(1,2,2)
lines2=plt.plot(RF_model.predict(X_train),y_train,'o',x,y,'k')
plt.setp(lines[0], markersize=7)
plt.setp(lines[1], linewidth=3)
plt.xlabel('Predicted')
plt.ylabel('Observed')
plt.title('Random Forest (train)')
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
x=np.linspace(80,120)
y=x
lines=plt.plot(Lin_model.predict(X_test),y_test,'o',x,y,'k')
plt.setp(lines[0], markersize=7)
plt.setp(lines[1], linewidth=3)
plt.xlabel('Predicted')
plt.ylabel('Observed')
plt.title('Linear Regression (test)')
plt.tight_layout()

plt.subplot(1,2,2)
lines2=plt.plot(RF_model.predict(X_test),y_test,'o',x,y,'k')
plt.setp(lines[0], markersize=7)
plt.setp(lines[1], linewidth=3)
plt.xlabel('Predicted')
plt.ylabel('Observed')
plt.title('Random Forest (test)')
plt.tight_layout()

plt.show()

# %%
from sklearn.model_selection import KFold

# %%
folds = KFold(random_state=42, n_splits=5, shuffle=True)

# %%
folds
# Out:
# KFold(n_splits=5, random_state=42, shuffle=True)

# %%
X = np.array(X_train)

# %%
y = np.array(y_train)

# %%
RMSE_history=[]

# %%
for train_index, valid_index in folds.split(X):
  X_train_2 = X[train_index]
  X_valid =  X[valid_index]
  y_train_2 = y[train_index]
  y_valid = y[valid_index]

  RF_model_2 = RandomForestRegressor(random_state=42, n_estimators=10, max_depth=4)
  RF_model_2.fit(X_train_2, y_train_2)

  y_pred = RF_model_2.predict(X_valid)
  RMSE_history.append(RMSE(y_valid,y_pred))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#
# ...

# %%
RMSE_history
# Out:
# [0.3035055796902015,
#  0.31113474502732863,
#  0.28779457125851526,
#  0.36114314078959886,
#  0.3277244300212474]

# %%
RMSE_history=[]
result_history = pd.DataFrame()

# %%
num = 0
for train_index, valid_index in folds.split(X):
  X_train_2 = X[train_index]
  X_valid =  X[valid_index]
  y_train_2 = y[train_index]
  y_valid = y[valid_index]

  RF_model_2 = RandomForestRegressor(random_state=42, n_estimators=10, max_depth=4)
  RF_model_2.fit(X_train_2, y_train_2)

  y_pred = RF_model_2.predict(X_valid)
  RMSE_history.append(RMSE(y_valid,y_pred))

  result_history['test'+str(num)] = RF_model_2.predict(X_test)
  num = num+1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# ...

# %%
result_history
# Out:
#           test0       test1       test2       test3       test4
# 0     94.022859   93.716081   93.805627   93.675921   94.038106
# 1     94.022859   93.716081   93.805627   93.675921   94.038106
# 2     94.022859   93.716081   93.805627   93.675921   94.038106
# 3     93.411237   93.730365   93.051817   93.633008   94.111106
# 4     93.668949   94.216195   93.051817   93.633008   94.339163
# ..          ...         ...         ...         ...         ...
# 98   104.356914  104.651449  104.362737  104.919353  104.457536
# 99   104.436774  104.651449  104.507713  104.919353  104.457536
# 100  104.436774  104.651449  104.507713  104.919353  104.457536
# 101  104.436774  104.651449  104.507713  104.919353  104.457536
# 102  104.583479  104.651449  104.609395  105.035489  104.542057
#
# [103 rows x 5 columns]

# %%
RMSE(y_test, np.array(result_history).mean(axis=1).reshape(len(X_test),1))
# Out:
# 매매가격지수    1.99982
# dtype: float64

# %%
RMSE_history
# Out:
# [0.3035055796902015,
#  0.31113474502732863,
#  0.28779457125851526,
#  0.36114314078959886,
#  0.3277244300212474]

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
x=np.linspace(80,120)
y=x
lines=plt.plot(RF_model.predict(X_test),y_test,'o',x,y,'k')
plt.setp(lines[0], markersize=7)
plt.setp(lines[1], linewidth=3)
plt.xlabel('Predicted')
plt.ylabel('Observed')
plt.title('Random Forest (test)')
plt.tight_layout()

plt.subplot(1,2,2)
lines2=plt.plot(np.array(result_history).mean(axis=1).reshape(len(X_test),1),y_test,'o',x,y,'k')
plt.setp(lines[0], markersize=7)
plt.setp(lines[1], linewidth=3)
plt.xlabel('Predicted')
plt.ylabel('Observed')
plt.title('KFold Random Forest (test)')
plt.tight_layout()

plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %%
RF_model_3 = RandomForestRegressor()

# %%
RMSE_scorer = metrics.make_scorer(RMSE, greater_is_better=False)

# %%
RF_prarms = {'n_estimators' : list(range(1,10,1)), 'max_depth' : list(range(1,10,1))}

# %%
GS_RF_model = GridSearchCV(estimator=RF_model_3, param_grid=RF_prarms, scoring=RMSE_scorer,cv=5)

# %%
GS_RF_model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:680: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
GS_RF_model.best_params_
# Out:
# {'max_depth': 8, 'n_estimators': 3}

# %%
GS_RF_model.best_estimator_.predict(X_train)
# Out:
# array([ 95.81553679,  95.81553679,  95.83837713,  95.81553679,
#         95.81553679,  95.86982233,  95.86982233,  95.94869119,
#         95.89885683,  95.93783477,  96.03160755,  96.00257305,
#         95.91441661,  95.81553679,  95.78606191,  95.84034745,
#         95.78606191,  95.83065619,  95.88494173,  95.55132502,
#         95.55132502,  95.5158981 ,  95.5158981 ,  95.52701353,
#         95.52701353,  95.52701353,  95.52701353,  95.52701353,
#         95.37291702,  95.37291702,  95.28404292,  95.23185073,
#         95.1066286 ,  95.1066286 ,  95.05629099,  94.77508378,
#         94.77508378,  94.77508378,  94.77508378,  94.74333804,
#         94.74333804,  94.74333804,  94.74333804,  94.64843293,
#         94.55298343,  94.55298343,  94.55298343,  94.64843293,
#         94.55298343,  94.64843293,  94.64843293,  94.79618362,
#         94.96124381,  94.81349312,  94.81349312,  94.96124381,
#         94.81587074,  94.81587074,  94.81587074,  94.81587074,
# ...

# %%
RMSE(y_train, GS_RF_model.best_estimator_.predict(X_train))
# Out:
# 매매가격지수    0.072432
# dtype: float64

# %%
RMSE(y_test, GS_RF_model.best_estimator_.predict(X_test))
# Out:
# 매매가격지수    1.863275
# dtype: float64

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
x=np.linspace(80,120)
y=x
lines=plt.plot(np.array(result_history).mean(axis=1).reshape(len(X_test),1),y_test,'o',x,y,'k')
plt.setp(lines[0], markersize=7)
plt.setp(lines[1], linewidth=3)
plt.xlabel('Predicted')
plt.ylabel('Observed')
plt.title('KFold Random Forest (test)')
plt.tight_layout()

plt.subplot(1,2,2)
lines2=plt.plot(GS_RF_model.best_estimator_.predict(X_test),y_test,'o',x,y,'k')
plt.setp(lines[0], markersize=7)
plt.setp(lines[1], linewidth=3)
plt.xlabel('Predicted')
plt.ylabel('Observed')
plt.title('GridCV Random Forest (test)')
plt.tight_layout()



plt.show()

# %%
def RMSLE(y_true, y_pred):
  y_pred=y_pred.reshape(len(y_pred),1) #모양을 다시 잡아줌으로써 에러 발생을 막음

  y_true = np.exp(y_true)
  y_pred = np.exp(y_pred)

  log_true = np.log(y_true+1)
  log_pred = np.log(y_pred+1)

  output = np.sqrt(np.mean((log_true-log_pred)**2))
  return output

# %%
log_y_train = np.log(y_train) #로그 변환
log_y_test = np.log(y_test)

# %%
DT_model_log = DecisionTreeRegressor(max_depth=4)
DT_model_log.fit(X_train, log_y_train) # X_train = 학습시키는 특성

DT_pred_train_log = DT_model.predict(X_train)
DT_pred_test_log = DT_model.predict(X_test)

# %%
RMSLE(log_y_train, DT_pred_train)

# %%
RMSLE(log_y_test, DT_pred_test)

# %%
print("특성 중요도:", DT_model_log.feature_importances_)

# %%
feature_importance=DT_model_log.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, np.array(X_train.columns)[sorted_idx])
plt.xlabel('Feature Importance')
plt.title('Feature Importance')
